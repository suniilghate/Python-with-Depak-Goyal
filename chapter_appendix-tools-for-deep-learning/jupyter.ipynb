# %% [markdown]
# <a href="https://colab.research.google.com/github/suniilghate/Python-with-Depak-Goyal/blob/main/chapter_appendix-tools-for-deep-learning/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
item1 = 100
item2 = 200
item3 = 400
sum = item1 + item2 + item3
tax = 10
total = sum + (sum * tax) / 100

print(total)
# Out:
# 770.0

# %%
# item1 = 100
# item2 = 200
# item3 = 400

item1 = 1000
item2 = 200
item3 = 400

sum = item1 + item2 + item3
tax = 10
total = 0

if sum < 1000 :
  total = sum + ((sum * tax) / 100)
else :
  total = sum

print(total)
# Out:
# 1600
